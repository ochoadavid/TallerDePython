# %% [markdown]
# ![Python Logo](img/Python_logo.png)
# <h1 align="center">Taller de Python para Profesores</h1>

# %% [markdown]
# <h1 align="center">Taller de Python para Profesores</h1>

# %% [markdown]
# <center>David Manuel Ochoa González<br>
# correos: ochoadavid at gmail.com - dochoa at iteso.mx<br>
# github: https://github.com/ochoadavid<br>
# material de apoyo en: https://github.com/ochoadavid/TallerDePython</center>

# %%
from IPython.display import Image
Image(filename='img/Python_logo.png', width=800)

# %% [markdown]
# ## Guido van Rossum

# %% [markdown]
# ![Guido](img/pycon-guido.jpg)

# %% [markdown]
# ### Python
#
# Van Rossum escribió en 1996:
#
# Hace seis años, en diciembre de 1989, estaba buscando un proyecto de programación como hobby que me mantuviera ocupado durante las semanas de Navidad. Mi oficina estaría cerrada y no tendría más que mi ordenador de casa a mano. Decidí escribir un intérprete para el nuevo lenguaje de scripting que había estado ideando recientemente: un descendiente de ABC que gustaría a los hackers de Unix/c. Elegí el nombre de Python para el proyecto, encontrándome en un estado de ánimo ligeramente irreverente (y siendo un gran fan de **Monty Python's Flying Circus**).

# %% [markdown]
# ## Programación para todos
#
# En el año 1999 Van Rossum realizó una propuesta a DARPA llamada Computer Programming for Everybody, en la que describió qué y cómo debería ser Python:

# %% [markdown]
# * Python debería ser fácil, intuitivo y tan potente como sus principales competidores.

# %% [markdown]
# * El proyecto sería de Código Abierto para que cualquiera pudiera colaborar.

# %% [markdown]
# * El código escrito en Python sería tan comprensible como cualquier texto en inglés.

# %% [markdown]
# * Python debería ser apto para las actividades diarias permitiendo la construcción de prototipos en poco tiempo.

# %% [markdown]
# Python es a día de hoy uno de los lenguajes de programación más populares. En 2011 se proclamó el tercer lenguaje más popular de la forja GitHub y según la encuesta se encuentra entre los 10 lenguajes de programación más demandados en las ofertas de trabajo.

# %% [markdown]
# ### El zen de Python:
#
# * Hermoso es mejor que feo.
# * Explícito es mejor que implícito.
# * Simple es mejor que complejo.
# * Complejo es mejor que complicado.
# * Sencillo es mejor que anidado.
# * Escaso es mejor que denso.
# * La legibilidad cuenta.
# * Los casos especiales no son lo suficientemente especiales para romper las reglas.
# * Lo práctico le gana a la pureza.
# * Los errores no deben pasar en silencio.
# * A menos que sean silenciados.
# * En cara a la ambigüedad, rechazar la tentación de adivinar.
# * Debe haber una - y preferiblemente sólo una - manera obvia de hacerlo.
# * Aunque esa manera puede no ser obvia en un primer momento a menos que seas holandés.
# * Ahora es mejor que nunca.
# * Aunque "nunca" es a menudo mejor que "ahora mismo".
# * Si la aplicación es difícil de explicar, es una mala idea.
# * Si la aplicación es fácil de explicar, puede ser una buena idea.
# * Los espacios de nombres son una gran idea ¡hay que hacer más de eso!

# %% [markdown]
# ![PEP-20](img/PEP-20.png)

# %% [markdown]
# ## Programación multi-paradigma
#
# Al igual que otros lenguajes Python es un lenguaje multiparadigma y podemos usarlo:
# * Con un archivo tipo script, donde el __procesamiento es lineal__ (del principio al fin).
# * Declarando __funciones__ que operan sobre variables.
# * Usando el paradigma de __programación orientada a objetos__ donde cada objeto tiene propiedades y métodos.
# * A manera de __conversa__ usando IPython.
# * Como una libreta o __notebook__ usando Jupyter.

# %% [markdown]
# ### Script:
# Usando un archivo de texto con el programa __ejemplo.py__:

# %%
#!/usr/bin/python3
# -*- coding: utf-8 -*-
## Autor: David Ochoa

print('¡Hola!')
# Out:
# ¡Hola!

# %% [markdown]
# ### Funciones:

# %%
def suma(a, b):
    """Suma dos valores."""
    return a + b

print(suma(5, 8))
# Out:
# 13

# %% [markdown]
# __Nota__: en Python se utiliza la sangría (_indent_) como parte del código, determinando donde empiezan y terminan las declaraciones, ciclos y condicionales. Aunque se puede usar cualquier sangria es comunmente preferido usar una sangría de __4 espacios__ por nivel. Esto es automáticamente hecho por varios IDE y por la interfase de IPython y Jupyter.

# %% [markdown]
# ### Programación orientada a objetos:
# Definimos una clase:

# %%
class Ventana():
    """Clase Ventana. Tiene una área definida, puede estar abierta o cerrada y puede o no 
    tener mosquitero"""
    def __init__(self, area, abierta, mosquitero = False):
        """Crea una ventana nueva. Necesita los valores del área (metros cuadrados), 
        si está abierta o no y opcionalmente se puede delcarar si tiene o no mosquitero"""
        self.area = area
        self.abierta = abierta
        self.mosquitero = mosquitero
    
    def abrir(self):
        """Abre la ventana."""
        self.abierta = True

    def cerrar(self):
        """Cierra la ventana."""
        self.abierta = False

# %%
help(Ventana)
# Out:
# Help on class Ventana in module __main__:
#
# class Ventana(builtins.object)
#  |  Clase Ventana. Tiene una área definida, puede estar abierta o cerrada y puede o no
#  |  tener mosquitero
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, area, abierta, mosquitero=False)
#  |      Crea una ventana nueva. Necesita los valores del área (metros cuadrados),
#  |      si está abierta o no y opcionalmente se puede delcarar si tiene o no mosquitero
#  |
#  |  abrir(self)
#  |      Abre la ventana.
#  |
#  |  cerrar(self)
#  |      Cierra la ventana.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# Y ahora creamos una instancia (objeto) tipo Ventana:

# %%
# Creamos la ventana_frontal:
ventana_frontal = Ventana(0.4*0.4, True)
# Utilizamos sus métodos y consultamos sus propiedades
print('La ventana frontal, ¿está abierta?')
print(ventana_frontal.abierta)
print('¿que área tiene?')
print(ventana_frontal.area)
ventana_frontal.cerrar()
print('Ahora, ¿está abierta?')
print(ventana_frontal.abierta)
# Out:
# La ventana frontal, ¿está abierta?
# True
# ¿que área tiene?
# 0.16000000000000003
# Ahora, ¿está abierta?
# False

# %% [markdown]
# ![Python Logo](img/ipython.jpg)
# ### IPython
# Es una interfase interactiva de Python que ofrece más funcionalidades que el interprete normal. Entre sus funcionalidades nos ofrece:
# * Completar nombres de objetos, funciones y variables con '__tab__'.
# * Ayuda de los objetos con ? (probar p.e. '__print?__').
# * Lista las variables y objetos en memoria con '__who__'.
# * Métodos '__%magic__'.

# %% [markdown]
# Una sessión podría ser:
#
#     Python 3.5.2+ (default, Sep 22 2016, 12:18:14)
#     Type "copyright", "credits" or "license" for more information.
#
#     IPython 2.4.1 -- An enhanced Interactive Python.
#     ?         -> Introduction and overview of IPython's features.
#     %quickref -> Quick reference.
#     help      -> Python's own help system.
#     object?   -> Details about 'object', use 'object??' for extra details.
#
#     In [1]: a = 5
#
#     In [2]: b = 3
#
#     In [3]: a + b
#     Out[3]: 8

# %% [markdown]
# ### Spyder
# ![Python Logo](img/Spyder.png)

# %% [markdown]
# ### Jupyter Notebook
# Presenta una interfase en web que trabaja con __cells__ que pueden ser ejecutadas indepedientemente. Incluye las funcionalidades de IPython pero además nos permite guardar (publicar, compartir) los resultados de nuestro código (archivos __\*.ipynb__).

# %% [markdown]
# ¡Las presentaciones de este taller fueron hechas usando Jupyter Notebook!
